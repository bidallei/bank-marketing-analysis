# %% [markdown]
# # 01 - Data Loading & Initial Inspection
#
# In this notebook we load the Bank Marketing dataset and perform an initial inspection to understand its structure, data types, and basic properties.
# This step ensures the data is correctly imported and ready for exploratory analysis.

# %%
# Importamos las bibliotecas necesarias
import pandas as pd
import numpy as np

# %%
DATA_PATH = "../data/bank-additional-full.csv"

df = pd.read_csv(DATA_PATH, sep=";")

# %%
print("Dataset shape:")
df.shape

# %%
df.head()
